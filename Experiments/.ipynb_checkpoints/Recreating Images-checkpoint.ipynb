# %% [markdown]
# # Recreating images
# Recreating images from the paper [Phase diagram for two-layer ReLU neural networks at
# infinite-width limit](https://arxiv.org/abs/2007.07497).

# %%
using LinearAlgebra
using Makie, CairoMakie

include("../MyTwoLayerNN/MyTwoLayerNN.jl")
import .MyTwoLayerNN

# %%
# Theme for plots 
set_theme!(theme_latexfonts())

# %% [markdown]
# Data and constants

# %%
d = 1 # Dimension of the data
dataX = [[-1/2], [-1/3], [1/3], [1/2]]
dataY = [0.25, 0.03, 0.03, 0.25]
# Out:
# 4-element Vector{Float64}:
#  0.25
#  0.03
#  0.03
#  0.25

# %% [markdown]
# ### Figure 2

# %%
# Creating the NN
m = 1_000
γ = 0.5
γ′ = 0.0
myNN = MyTwoLayerNN.TwoLayerNN(d, m, γ, γ′)

# Creating the training data
learning_rate = 100_000.0
steps::Int32 = 200_000
myTrainingData = MyTwoLayerNN.TrainingData(dataX, dataY, learning_rate, steps)

# Create copy of initial weights and biases
initParms = (a = copy(myNN.a), w = copy(myNN.w), b = copy(myNN.b))
# Out:
# (a = [-1.1572271812776425, 0.5163557827699525, 0.15488256572070214, 0.6224470788313031, -0.055729108822347995, 0.3728268447227626, -0.22015055011026352, 1.198946145848835, -0.043172305346507726, 1.1184072813119557  …  -0.09107909867584546, 0.15795949091918796, 0.3343702370328856, 0.7877954035680083, -0.10300730204311556, -0.5266595147079736, -2.3365397625835205, 3.0079735477779868, -0.505834532453238, 0.3165263443831178], w = [0.8082879284649668; -1.1220725081141734; … ; -0.7939655795031201; 1.0595933534256632;;], b = [-0.47496715358102554, 1.148888755532331, -2.367065313683067, -0.1413271433288235, 0.23670585773847655, -0.4517461495767685, -2.3186353376297686, -0.9157785755134368, 1.2326388134577464, 0.13282887253155098  …  -0.08685272178800885, -1.0213893124763616, 0.31031723883579676, 0.614048163039896, 1.0400911111808686, -0.6082465480388745, 0.6501533330676467, 0.711915178845212, -1.5144513946057814, 1.7648532672085873])

# %%
# Train the NN 
MyTwoLayerNN.train!(myNN, myTrainingData)
# Out:
# Risk = 0.006027168717489424
# Risk = 0.005283601407323053
# Risk = 0.0007475602028267025
# Risk = 2.5302566546448723e-6
# Number of steps: 41444

# %%
# Create plot 
f = Figure()
ax = Axis(f[1, 1], xticks=-0.4:0.2:0.4)

# Plot NN 
x = range(-0.5, 0.5, length=100)
y = [MyTwoLayerNN.forward(myNN, p) for p in x]

lines!(ax, x, y, color=:darkorange2)

# Data points
scatter!(ax, vcat(dataX...), dataY)

f

# %%
save("line gamma 1.75.pdf", f)
# Out:
# CairoMakie.Screen{PDF}

# %% [markdown]
# #### Scatter plot
# Amplitude is calculated using: $A_i = |a_i|\cdot \|(w_i, b_i)\|_2$.
#
# Angle is calculated using: $\phi_j = \arg(w_j + b_j\cdot i)$

# %%
# Orientation plot 
f = Figure()
ax = Axis(f[1, 1], xticks=-3:1:3, xlabel="Orientation", ylabel="Amplitude")

xlims!(ax, -π, π)

# Calculate amplitude
ampInit = abs.(initParms.a) .* norm.(eachrow([initParms.w initParms.b]))
ampNew = abs.(myNN.a) .* norm.(eachrow([myNN.w myNN.b]))

# Calculate orientation
oriInit = angle.(vec(initParms.w) + im * initParms.b)
oriNew = angle.(vec(myNN.w) + im * myNN.b)

# Create plot
scatInit = scatter!(ax, oriInit, ampInit, strokewidth=0.5)
scatNew = scatter!(ax, oriNew, ampNew, color=:darkorange2, strokewidth=0.5)

axislegend(ax, [scatInit, scatNew], ["Before training", "After training"])

f

# %%
save("orientation gamma 1.75.pdf", f)
# Out:
# CairoMakie.Screen{PDF}
